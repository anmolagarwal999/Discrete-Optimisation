# %%
import pandas as pd

# %%
data_obj = pd.read_csv("./ipl_data/Match.csv")

# %%
data_obj
# Out:
#      Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 0      335987  18-Apr-08             2                 1          1
# 1      335988  19-Apr-08             4                 3          1
# 2      335989  19-Apr-08             6                 5          1
# 3      335990  20-Apr-08             7                 2          1
# 4      335991  20-Apr-08             1                 8          1
# ..        ...        ...           ...               ...        ...
# 572    981016  22-May-16             6                 2          9
# 573    981018  24-May-16            13                 2          9
# 574    981020  25-May-16            11                 1          9
# 575    981022  27-May-16            13                11          9
# 576    981024  29-May-16             2                11          9
#
#                                            Venue_Name  Toss_Winner_Id  \
# 0                               M Chinnaswamy Stadium               2
# ...

# %%
data_obj_2 = pd.read_csv("./ipl_data/Team.csv")

# %%
data_obj_2
# Out:
#     Team_Id                    Team_Name Team_Short_Code
# 0         1        Kolkata Knight Riders             KKR
# 1         2  Royal Challengers Bangalore             RCB
# 2         3          Chennai Super Kings             CSK
# 3         4              Kings XI Punjab            KXIP
# 4         5             Rajasthan Royals              RR
# 5         6             Delhi Daredevils              DD
# 6         7               Mumbai Indians              MI
# 7         8              Deccan Chargers              DC
# 8         9         Kochi Tuskers Kerala             KTK
# 9        10                Pune Warriors              PW
# 10       11          Sunrisers Hyderabad             SRH
# 11       12      Rising Pune Supergiants             RPS
# 12       13                Gujarat Lions              GL

# %%
data_obj.loc[data_obj['Season_Id'] == 9]
# Out:
#      Match_Id Match_Date  Team_Name_Id  Opponent_Team_Id  Season_Id  \
# 517    980906   9-Apr-16             7                12          9
# 518    980908  10-Apr-16             1                 6          9
# 519    980910  11-Apr-16             4                13          9
# 520    980912  12-Apr-16             2                11          9
# 521    980914  13-Apr-16             1                 7          9
# 522    980916  14-Apr-16            13                12          9
# 523    980918  15-Apr-16             6                 4          9
# 524    980920  16-Apr-16            11                 1          9
# 525    980922  16-Apr-16             7                13          9
# 526    980924  17-Apr-16             4                12          9
# 527    980926  17-Apr-16             2                 6          9
# 528    980928  18-Apr-16            11                 7          9
# 529    980930  19-Apr-16             4                 1          9
# ...

# %%
data_9=data_obj.loc[data_obj['Season_Id'] == 9][['Team_Name_Id','Opponent_Team_Id','Match_Winner_Id']]

# %%
data_9
# Out:
#      Team_Name_Id  Opponent_Team_Id  Match_Winner_Id
# 517             7                12             12.0
# 518             1                 6              1.0
# 519             4                13             13.0
# 520             2                11              2.0
# 521             1                 7              7.0
# 522            13                12             13.0
# 523             6                 4              6.0
# 524            11                 1              1.0
# 525             7                13             13.0
# 526             4                12              4.0
# 527             2                 6              6.0
# 528            11                 7             11.0
# 529             4                 1              1.0
# 530             7                 2              7.0
# 531            13                11             11.0
# 532            12                 2              2.0
# 533             6                 7              6.0
# ...

# %%
map_data={1:"KKR",
          2:"RCB",
          3:"CSK",
          4:"KXIP",
          5:"RR",
          6:"DD",
          7:"MI",
          8:"DC",
          9:"CTK",
          10:"PWI",
          11:"SRH",
          12:"RSP",
          13:"GL"    
    
}

# %%
data_9['Team_Name_Id']=data_9['Team_Name_Id'].map(map_data)
data_9['Opponent_Team_Id']=data_9['Opponent_Team_Id'].map(map_data)
data_9['Match_Winner_Id']=data_9['Match_Winner_Id'].map(map_data)

# %%
data_9
# Out:
#     Team_Name_Id Opponent_Team_Id Match_Winner_Id
# 517           MI              RSP             RSP
# 518          KKR               DD             KKR
# 519         KXIP               GL              GL
# 520          RCB              SRH             RCB
# 521          KKR               MI              MI
# 522           GL              RSP              GL
# 523           DD             KXIP              DD
# 524          SRH              KKR             KKR
# 525           MI               GL              GL
# 526         KXIP              RSP            KXIP
# 527          RCB               DD              DD
# 528          SRH               MI             SRH
# 529         KXIP              KKR             KKR
# 530           MI              RCB              MI
# 531           GL              SRH             SRH
# 532          RSP              RCB             RCB
# 533           DD               MI              DD
# 534          SRH             KXIP             SRH
# ...
